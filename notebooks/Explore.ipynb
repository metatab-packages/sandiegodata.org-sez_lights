# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
pkg = mp.jupyter.open_package()
#pkg = mp.jupyter.open_source_package()
pkg
# Out:
# # SEZ Lights, Rings and Buffers
# `sandiegodata.org-sez_lights-1.1.1` Last Update: 2021-09-08T22:22:34
#
# _Sums of pixel values representing nighttime light intensit, for buffers and rings around Special Economic Zones._
#
#
#
#
#
#
# ## Contacts
#
# * **Wrangler** [Eric Busboom](mailto:eric@civicknowledge.com), [Civic Knowledge](http://civicknowledge.com)
#
# ## Resources
#
# * ** [mean_lights](data/mean_lights.csv)**. Pixel light sums for buffers and rings around the SEZ.
#
# ## References
# <ul><li> <strong>sez</string>, <em>metapack+http://library.metatab.org/worldbank.org-sez-1.1.1.csv#sez</em>. SEZ Locations and data</li><li> <strong>ntl</string>, <em>metapack+http://library.metatab.org/figshare.com-harmonized_ntl-1.1.1.csv</em>. Harmonized Nighttime lights</li><ul>

# %%
sez = pkg.reference('sez').geoframe()
ml = pkg.resource('mean_lights').dataframe()

# %%
pkg.resource('mean_lights')
# Out:
# <Resource: metadata.csv 33:1 root.datafile data/mean_lights.csv ['mean_lights', 'Pixel light sums for buffers and rings around the SEZ.', '']>

# %%
t = sez.merge(ml[ml.year == 2017])
t[t.country_code == 'URY'].head()
# Out:
#       id unique_id check   latitude  longitude country_code  \
# 0      0     URY12   URY -33.887443 -58.416899          URY
# 1      0     URY12   URY -33.887443 -58.416899          URY
# 2      1      URY2   URY -34.470636 -57.831424          URY
# 3      1      URY2   URY -34.470636 -57.831424          URY
# 206  103      URY1   URY -34.787515 -56.071706          URY
#
#     country_type_combo region  country  zone_type  ... note  \
# 0         URYFree Zone    LAC  Uruguay  Free Zone  ...  NaN
# 1         URYFree Zone    LAC  Uruguay  Free Zone  ...  NaN
# 2         URYFree Zone    LAC  Uruguay  Free Zone  ...  NaN
# 3         URYFree Zone    LAC  Uruguay  Free Zone  ...  NaN
# 206       URYFree Zone    LAC  Uruguay  Free Zone  ...  NaN
#
#                         geometry  year buffer_pix_sum buffer_pix_count  \
# 0    POINT (-58.41690 -33.88744)  2017           3097              110
# 1    POINT (-58.41690 -33.88744)  2017           5490              437
# 2    POINT (-57.83142 -34.47064)  2017           2649              120
# 3    POINT (-57.83142 -34.47064)  2017           5271              414
# 206  POINT (-56.07171 -34.78751)  2017           4053              120
#
#     ring_pix_sum ring_pix_count   buffer_area     ring_area radius
# 0           1139            238  7.841371e+07  7.841371e+07   5000
# 1           2200            806  3.136548e+08  3.136548e+08  10000
# 2           1244            224  7.841371e+07  7.841371e+07   5000
# 3           2167            806  3.136548e+08  3.136548e+08  10000
# 206         4364            224  7.841371e+07  7.841371e+07   5000
#
# [5 rows x 70 columns]

# %%
df = sez.merge(ml)
